# %% [markdown]
# <h1>MySQL and Airtable Data Access</h1>

# %%
# !pip install PyMySQL

# %%
import pymysql.cursors
connection = pymysql.connect(host="localhost", 
                     user="root",   
                     passwd="root", 
                     db="com5940_assign",   
                     charset='utf8mb4',
                     cursorclass=pymysql.cursors.DictCursor)

# %%
with connection.cursor() as cursor:
        sql = "SELECT * FROM mytable"
        cursor.execute(sql)
        result = cursor.fetchall()
        dataset = []
        temp = {}
        i = 0
        for row in result:
            temp[i] = row
            dataset.append(temp[i])
            i = i + 1
        print('\n')
        print(dataset)
        print('\n')
# Out:
# [{'painting_name': 'A Bar at the Folies-Bergère', 'author': 'Édouard Manet', 'artist': 'Édouard Manet', 'year': 1882, 'photo': 'P-1934-SC-234-tif-15319.jpg (https://dl.airtable.com/.attachments/747eedc69dd37860bdbf931280cc8e8a/b47b427e/P-1934-SC-234-tif-15319.jpg)', 'synopsis': 'This painting was Manet’s last major work. It represents the bustling interior of one of the most prominent music halls and cabarets of Paris, the Folies-Bergère. The venue opened in 1869 and its atmosphere was described as “unmixed joy”. In contrast, the barmaid in Manet’s representation is detached and marooned behind the bar.\r\n\r\nThe Folies-Bergère was also notorious as a place to pick up prostitutes. The writer Guy de Maupassant described the barmaids as “vendors of drink and of love”.\r\n\r\nManet knew the place well. He made a number of preparatory sketches there but the final work was painted in his studio. He set up a bar and asked one of the barmaids, Suzon, to serve as his model.\r\n\r\nThe paint
# ...

# %%
# !pip install requests

# %%
import requests

headers = {
'Authorization': 'Bearer keywrQWiluRxtIAp8',
}

params = (
('view', 'Grid view'),
)

r = requests.get('https://api.airtable.com/v0/appbH7TRmDavRetpi/painting_number?api_key=keywrQWiluRxtIAp8', headers=headers, params=params)
dict = r.json()
dataset = []
painting_name = []
artist = []
year = []
for i in dict['records']:
     dict = i['fields']
     dataset.append(dict)
print(dataset)
print('\n')
for dicts in dataset:
    painting_name.append(dicts.get('painting_name'))
    artist.append(dicts.get('artist'))
    year.append(dicts.get('year'))
print(year)
# Out:
# [{'artist_name': 'Claude Monet', 'Top 58 Most Expensive Paintings': ['rec6Mln5E0jzkxUl5', 'recyhHs6U6EuwAo8e', 'rec67tP4m4WCf0WDR', 'recNYY2MtPCqCAnHu', 'rec3bHRhxZmrhTEUO', 'recvdIWzz7JZ5MN8I', 'recCdl5DyvPo9gZ1B', 'recbfaubVKGfemHdR', 'recswxZyG6LQTuvl2', 'recA8FO7OpgnVBeh6', 'recN7taIRyGsr67vT', 'rect8OrjL1PJ2Cdlb', 'recHRwDCE58qTBwCh', 'recWidEEgmUOHVWc0', 'recZoNxsaWhAhb1GI', 'rec0YIdrX9FD29fiE', 'recvcPBNrVH5XJQBd', 'recI7jchZmQwliDAn', 'reck84RGs0Vm4Nr53', 'rec8MRc9o69QWdeDR', 'recfHxKZAbGEZaocW', 'rec8BLbRDoVgN7kkk', 'recpxIdaxJMIqJhVx', 'recC3S7vHpsBlKwel', 'recRGlX5BSWDRAfjO', 'recFiPbsCZGSVdC4o', 'recF707DTCKwYY9uj', 'recnSTodTubVhBa5r', 'recEC19Ese2qPwIhT'], 'Artist': ['reccnWGyBbZolcVVp'], 'Photos': [{'id': 'attrprCXJGEFZdzJN', 'url': 'https://dl.airtable.com/.attachments/2eae4b5c9f9bb4c1428ce4a7e2cb749f/b614d628/1024px-Claude_Monet_1899_Nadar_crop.jpg', 'filename': '1024px-Claude_Monet_1899_Nadar_crop.jpg', 'size': 170414, 'type': 'image/jpeg', 'thumbnails': {'small': {
# ...
