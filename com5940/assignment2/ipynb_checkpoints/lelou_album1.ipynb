# %%
import requests
import pandas as pd 
headers = {
'Authorization': 'Bearer keywrQWiluRxtIAp8',
}

params = (
('view', 'Grid view'),
)

r = requests.get('https://api.airtable.com/v0/app5yrY9cMq8MJEwI/Album?api_key=keywrQWiluRxtIAp8', headers=headers, params=params)
dict = r.json()
dataset = []
Name = []
Date = []
Location = []
Photo = []
for i in dict['records']:
     dict = i['fields']
     dataset.append(dict)
print(dataset)
print('\n')
print(pd.DataFrame(dataset))
print('\n')
for dicts in dataset:
    Name.append(dicts.get('Name'))
    Date.append(dicts.get('Date'))
    Location.append(dicts.get('Location'))
    Photo.append(dicts.get('Photo'))
print(Name)
df = pd.DataFrame(Name)
print(pd.DataFrame(Name))

print("Showing first 5 entries",df.head(5))
# Out:
# [{'Name': 'Seaside', 'Time': '2019-08-27', 'Photo': [{'id': 'attpHHTWvw0iDDcj0', 'url': 'https://dl.airtable.com/.attachments/3fa89bc77646a4ad671112ddc381c579/e9eb9710/DSC_0135.jpg', 'filename': 'DSC_0135.jpg', 'size': 11827271, 'type': 'image/jpeg', 'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/30735c86a0654cc7e7e9da2d49205552/a0c093f1', 'width': 54, 'height': 36}, 'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/7dfa56d4cfa6f794a303578b141d1f19/76d236dc', 'width': 768, 'height': 512}, 'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/d0879b0c0b9edcddb12043d73a8aeed3/85ff98ca', 'width': 3000, 'height': 3000}}}], 'Location': 'Nanya Island, Hong Kong', 'Date': '20190827'}, {'Name': 'Kissing the Cliff', 'Time': '2019-04-27', 'Photo': [{'id': 'attEKMXztlHfHKdX8', 'url': 'https://dl.airtable.com/.attachments/2ce942b770964620ad664f0899415c66/14f09826/DSC_0332.jpg', 'filename': 'DSC_0332.jpg', 'size': 15528465, 'type': 'image/jpeg', 'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/d72d945ef871e6f6ef2de2da5b0e8ef6/0f2412a8', 'width': 54, 'height': 36}, 'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/749b7969a65ea73aa1c4d40ed1a91e77/5a1e918c', 'width': 768, 'height': 512}, 'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/b10012267f9af27dc87cc34ee3e577cf/a35111aa', 'width': 3000, 'height': 3000}}}], 'Location': 'Zhoushan, Zhejiang, China', 'Date': '20190427'}, {'Name': 'When Humans Vanishing', 'Time': '2019-04-27', 'Photo': [{'id': 'attJEbldtNsf7mxVO', 'url': 'https://dl.airtable.com/.attachments/6fe5ed0abfa2ea4a0e30858a667d23c7/178a773a/DSC_0236.jpg', 'filename': 'DSC_0236.jpg', 'size': 10851809, 'type': 'image/jpeg', 'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/b6a4b6a361dd30a930bb138f6bdc06e5/f5766641', 'width': 54, 'height': 36}, 'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/e6ccbbac5196080610896cb7fa924af7/7e26dad7', 'width': 772, 'height': 512}, 'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/71761367fa85d627bde6d0dfea9f8328/ea6015f8', 'width': 3000, 'height': 3000}}}], 'Location': 'Zhoushan, Zhejiang, China', 'Date': '20190427'}, {'Name': 'Flower Rain', 'Time': '2019-03-27', 'Photo': [{'id': 'attWeZcUO5DwvrCy2', 'url': 'https://dl.airtable.com/.attachments/ca10936f8c2295e7d9e60e5dd77db3f0/587df3be/DSC_1024.jpg', 'filename': 'DSC_1024.jpg', 'size': 5858159, 'type': 'image/jpeg', 'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/98d9ff75f968a2f9abd5d29e987ca742/c2668665', 'width': 56, 'height': 36}, 'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/085037b115b6734e4d17b91c56a8e82d/4e17c279', 'width': 800, 'height': 512}, 'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/498bba97e9733881d83a825d5b5e0b6c/6e632334', 'width': 3000, 'height': 3000}}}], 'Location': 'Hangzhou, Zhejiang, China', 'Date': '20190327'}, {'Name': 'Sky like a Circle', 'Time': '2017-03-14', 'Photo': [{'id': 'attWr7Pea3PWYheOi', 'url': 'https://dl.airtable.com/.attachments/b9af8452c54bf6b1cf527454278943fb/ba0a5d72/DSC_0508.JPG', 'filename': 'DSC_0508.JPG', 'size': 7341336, 'type': 'image/jpeg', 'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/797c44378f20c9d556d6739d52f537a9/a3fb8023', 'width': 54, 'height': 36}, 'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/f7c882a1256d0fc2d76880f1525c7b51/a69f8dfe', 'width': 768, 'height': 512}, 'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/084f4090f2cf5a2586d45ccbfb395dac/9e09492d', 'width': 3000, 'height': 3000}}}], 'Location': 'Hangzhou, Zhejiang, China', 'Date': '20170314'}, {'Name': 'Focus', 'Time': '2017-04-13', 'Photo': [{'id': 'attG1fMyB2LS4kXcW', 'url': 'https://dl.airtable.com/.attachments/053f189b49e51bd89df0e0ee42ae1e07/4066f547/focus.jpg', 'filename': 'focus.jpg', 'size': 8820104, 'type': 'image/jpeg', 'thumbnai ...
#
#
#                                 Name        Time  \
# 0                            Seaside  2019-08-27
# 1                  Kissing the Cliff  2019-04-27
# 2              When Humans Vanishing  2019-04-27
# 3                        Flower Rain  2019-03-27
# 4                  Sky like a Circle  2017-03-14
# 5                              Focus  2017-04-13
# 6                California Dreaming  2017-07-15
# 7                             Sunset  2017-07-17
# 8             Village in Kanas' Arms  2017-09-08
# 9                             Heaven  2017-09-11
# 10                               Ash  2018-07-20
# 11                     Road to Light  2018-07-22
# 12                   Train to Spring  2019-03-27
# 13         Lighthouse in the Eastest  2019-04-27
# 14                          Eternity  2019-04-27
# 15                Glory of Hong Kong  2019-08-21
# 16                          Daydream  2019-08-22
# 17  Crush between History and Modern  2019-08-22
# 18                      CUHK Secrets  2019-08-26
# 19                Chung King Mansion  2019-09-07
# 20                  Once Upon A Time  2019-05-04
#
#                                                 Photo  \
# 0   [{'id': 'attpHHTWvw0iDDcj0', 'url': 'https://d...
# 1   [{'id': 'attEKMXztlHfHKdX8', 'url': 'https://d...
# 2   [{'id': 'attJEbldtNsf7mxVO', 'url': 'https://d...
# 3   [{'id': 'attWeZcUO5DwvrCy2', 'url': 'https://d...
# 4   [{'id': 'attWr7Pea3PWYheOi', 'url': 'https://d...
# 5   [{'id': 'attG1fMyB2LS4kXcW', 'url': 'https://d...
# 6   [{'id': 'attJ7gkPFXj1mOxx4', 'url': 'https://d...
# 7   [{'id': 'attSQSNINU2Ucy1dJ', 'url': 'https://d...
# 8   [{'id': 'attOTZRlcBd44MQU3', 'url': 'https://d...
# 9   [{'id': 'attxvmcci4Ytx6Iv7', 'url': 'https://d...
# 10  [{'id': 'attSQMbaCmNddXQqh', 'url': 'https://d...
# 11  [{'id': 'attWhiSsfg3osKwCn', 'url': 'https://d...
# 12  [{'id': 'attqQZ8wbRchXK3Pn', 'url': 'https://d...
# 13  [{'id': 'attnnBrjWtn1aZVKQ', 'url': 'https://d...
# 14  [{'id': 'attlsXm7rLjkt8zom', 'url': 'https://d...
# 15  [{'id': 'attnCd1vrWy1kA0yt', 'url': 'https://d...
# 16  [{'id': 'att9b2fxLvYigML67', 'url': 'https://d...
# 17  [{'id': 'att3KMUSpnx9g6JTa', 'url': 'https://d...
# 18  [{'id': 'attX5TuuuOcC1gJr7', 'url': 'https://d...
# 19  [{'id': 'attWf29112D2y9ubu', 'url': 'https://d...
# 20  [{'id': 'attkgVJ5c14fdPX2d', 'url': 'https://d...
#
#                        Location      Date       Notes
# 0       Nanya Island, Hong Kong  20190827         NaN
# 1     Zhoushan, Zhejiang, China  20190427         NaN
# 2     Zhoushan, Zhejiang, China  20190427         NaN
# 3     Hangzhou, Zhejiang, China  20190327         NaN
# 4     Hangzhou, Zhejiang, China  20170314         NaN
# 5     Hangzhou, Zhejiang, China  20170413         NaN
# 6               California, USA  20170715         NaN
# 7               California, USA  20170717         NaN
# 8        Altay, Xinjiang, China  20170908         NaN
# 9      Kashgar, Xinjiang, China  20170911         NaN
# 10                   Oxford, UK  20180720         NaN
# 11                Greenwich, UK  20180722         NaN
# 12    Hangzhou, Zhejiang, China  20190327  Baita Park
# 13    Zhoushan, Zhejiang, China  20190427         NaN
# 14    Zhoushan, Zhejiang, China  20190427         NaN
# 15  Victoria Harbour, Hong Kong  20190821         NaN
# 16   Ruinas de Sao Paulo, Macau  20190822         NaN
# 17                        Macau  20190822         NaN
# 18        University, Hong Kong  20190826         NaN
# 19            Jordan, Hong Kong  20190907         NaN
# 20  Harbin, Heilongjiang, China  20190504         NaN
#
#
# ['Seaside', 'Kissing the Cliff', 'When Humans Vanishing', 'Flower Rain', 'Sky like a Circle', 'Focus', 'California Dreaming', 'Sunset', "Village in Kanas' Arms", 'Heaven', 'Ash', 'Road to Light', 'Train to Spring', 'Lighthouse in the Eastest', 'Eternity', 'Glory of Hong Kong', 'Daydream', 'Crush between History and Modern', 'CUHK Secrets', 'Chung King Mansion', 'Once Upon A Time']
#                                    0
# 0                            Seaside
# 1                  Kissing the Cliff
# 2              When Humans Vanishing
# 3                        Flower Rain
# 4                  Sky like a Circle
# 5                              Focus
# 6                California Dreaming
# 7                             Sunset
# 8             Village in Kanas' Arms
# 9                             Heaven
# 10                               Ash
# 11                     Road to Light
# 12                   Train to Spring
# 13         Lighthouse in the Eastest
# 14                          Eternity
# 15                Glory of Hong Kong
# 16                          Daydream
# 17  Crush between History and Modern
# 18                      CUHK Secrets
# 19                Chung King Mansion
# 20                  Once Upon A Time
# Showing first 5 entries                        0
# 0                Seaside
# 1      Kissing the Cliff
# 2  When Humans Vanishing
# 3            Flower Rain
# 4      Sky like a Circle

# %%
from flask import Flask, render_template, jsonify
import pymysql.cursors #initialise PyMysql module
import pandas as pd # initialise pandas module *********
connection = pymysql.connect(host="localhost", 
                     user="root",   
                     passwd="root", 
                     db="lelou_album",   
                     charset='utf8mb4',
                     cursorclass=pymysql.cursors.DictCursor)
with connection.cursor() as cursor:
        # Execute SQL Select command in Python using PyMysql built-in methods 
        sql = "SELECT * FROM album"
        cursor.execute(sql)
        # Display results
        result = cursor.fetchall()
print(result)
print(pd.DataFrame(result)) # ********
print('\n')
connection.close()
# Out:
# [{'Name': 'Seaside', 'Date': '20190827', 'Location': 'Nanya Island, Hong Kong', 'photo_url': 'https://dl.airtable.com/.attachments/3fa89bc77646a4ad671112ddc381c579/e9eb9710/DSC_0135.jpg'}, {'Name': 'Kissing the Cliff', 'Date': '20190427', 'Location': 'Zhoushan, Zhejiang, China', 'photo_url': 'https://dl.airtable.com/.attachments/2ce942b770964620ad664f0899415c66/14f09826/DSC_0332.jpg'}, {'Name': 'When Humans Vanishing', 'Date': '20190427', 'Location': 'Zhoushan, Zhejiang, China', 'photo_url': 'https://dl.airtable.com/.attachments/6fe5ed0abfa2ea4a0e30858a667d23c7/178a773a/DSC_0236.jpg'}, {'Name': 'Flower Rain', 'Date': '20190327', 'Location': 'Hangzhou, Zhejiang, China', 'photo_url': 'https://dl.airtable.com/.attachments/ca10936f8c2295e7d9e60e5dd77db3f0/587df3be/DSC_1024.jpg'}, {'Name': 'Sky like a Circle', 'Date': '20170314', 'Location': 'Hangzhou, Zhejiang, China', 'photo_url': 'https://dl.airtable.com/.attachments/b9af8452c54bf6b1cf527454278943fb/ba0a5d72/DSC_0508.JPG'}, {'Name': 'Focus', 'Date': '20170413', 'Location': 'Hangzhou, Zhejiang, China', 'photo_url': 'https://dl.airtable.com/.attachments/053f189b49e51bd89df0e0ee42ae1e07/4066f547/focus.jpg'}, {'Name': 'California Dreaming', 'Date': '20170715', 'Location': 'California, USA', 'photo_url': 'https://dl.airtable.com/.attachments/af76d516636e26c6645097793101ed0b/61f04cdc/DSC_0503.jpg'}, {'Name': 'Sunset', 'Date': '20170717', 'Location': 'California, USA', 'photo_url': 'https://dl.airtable.com/.attachments/9f2346d1d9c9f4d239ebec2e58885a1f/e3ab7321/DSC_0385.JPG'}, {'Name': "Village in Kanas' Arms", 'Date': '20170908', 'Location': 'Altay, Xinjiang, China', 'photo_url': 'https://dl.airtable.com/.attachments/15840476930046b95140eff4353bf76f/e67cb119/DSC_0296.jpg'}, {'Name': 'Heaven', 'Date': '20170911', 'Location': 'Kashgar, Xinjiang, China', 'photo_url': 'https://dl.airtable.com/.attachments/9fdb700e81fc93a91f6a1ad9fe52d9ef/a708124f/heaven.jpg'}, {'Name': 'Ash', 'Date': '20180720', 'Location': 'Oxford, UK', 'photo_url': 'https://dl.airtable.com/.attachments/198f07e19ee836eac67f5570739376ad/38db8dbe/ash.jpg'}, {'Name': 'Road to Light', 'Date': '20180722', 'Location': 'Greenwich, UK', 'photo_url': 'https://dl.airtable.com/.attachments/db3690fc2b7a6bd5c37878494ecfd0b9/8740ecef/-1.jpg'}, {'Name': 'Train to Spring', 'Date': '20190327', 'Location': 'Hangzhou, Zhejiang, China', 'photo_url': 'https://dl.airtable.com/.attachments/b8b94f63d75680e481d853b464a84314/1bc1aa7d/spring_trian.jpg'}, {'Name': 'Lighthouse in the Eastest', 'Date': '20190427', 'Location': 'Zhoushan, Zhejiang, China', 'photo_url': 'https://dl.airtable.com/.attachments/d97f77aa31f16fb1ecf1d1d17bacad0d/f927e9ae/lighthouse_eastest.jpg'}, {'Name': 'Eternity', 'Date': '20190427', 'Location': 'Zhoushan, Zhejiang, China', 'photo_url': 'https://dl.airtable.com/.attachments/60652ecfec9b4cd96b43cf5950258898/ad9b53d4/eternity.jpg'}, {'Name': 'Glory of Hong Kong', 'Date': '20190821', 'Location': 'Victoria Harbour, Hong Kong', 'photo_url': 'https://dl.airtable.com/.attachments/2bba5361c80b870a2c54ebd941b20b38/246dcbf9/DSC_0133.jpg'}, {'Name': 'Daydream', 'Date': '20190822', 'Location': 'Ruinas de Sao Paulo, Macau', 'photo_url': 'https://dl.airtable.com/.attachments/4009867b0158e2ed87a2cac95796080d/a128bd2c/DSC_0068.jpg'}, {'Name': 'Crush between History and Modern', 'Date': '20190822', 'Location': 'Macau', 'photo_url': 'https://dl.airtable.com/.attachments/c76c125edb8aef9b0e002c5f29f27e89/414279f1/DSC_0134.jpg'}, {'Name': 'CUHK Secrets', 'Date': '20190826', 'Location': 'University, Hong Kong', 'photo_url': 'https://dl.airtable.com/.attachments/63879fb92cb8c2ab3b3ce426452c558e/b89144a9/DSC_0218.jpg'}, {'Name': 'Chung King Mansion', 'Date': '20190907', 'Location': 'Jordan, Hong Kong', 'photo_url': 'https://dl.airtable.com/.attachments/48d0910369f78f9a4e4352675fbcf354/44eb94fb/DSC_0126.jpg'}, {'Name': 'Once Upon A Time', 'Date': '20190504', 'Location': 'Harbin, Heilongjiang, China', 'photo_url': 'https://dl.airtable.com/.attachmen ...
#                                 Name      Date                     Location  \
# 0                            Seaside  20190827      Nanya Island, Hong Kong
# 1                  Kissing the Cliff  20190427    Zhoushan, Zhejiang, China
# 2              When Humans Vanishing  20190427    Zhoushan, Zhejiang, China
# 3                        Flower Rain  20190327    Hangzhou, Zhejiang, China
# 4                  Sky like a Circle  20170314    Hangzhou, Zhejiang, China
# 5                              Focus  20170413    Hangzhou, Zhejiang, China
# 6                California Dreaming  20170715              California, USA
# 7                             Sunset  20170717              California, USA
# 8             Village in Kanas' Arms  20170908       Altay, Xinjiang, China
# 9                             Heaven  20170911     Kashgar, Xinjiang, China
# 10                               Ash  20180720                   Oxford, UK
# 11                     Road to Light  20180722                Greenwich, UK
# 12                   Train to Spring  20190327    Hangzhou, Zhejiang, China
# 13         Lighthouse in the Eastest  20190427    Zhoushan, Zhejiang, China
# 14                          Eternity  20190427    Zhoushan, Zhejiang, China
# 15                Glory of Hong Kong  20190821  Victoria Harbour, Hong Kong
# 16                          Daydream  20190822   Ruinas de Sao Paulo, Macau
# 17  Crush between History and Modern  20190822                        Macau
# 18                      CUHK Secrets  20190826        University, Hong Kong
# 19                Chung King Mansion  20190907            Jordan, Hong Kong
# 20                  Once Upon A Time  20190504  Harbin, Heilongjiang, China
#
#                                             photo_url
# 0   https://dl.airtable.com/.attachments/3fa89bc77...
# 1   https://dl.airtable.com/.attachments/2ce942b77...
# 2   https://dl.airtable.com/.attachments/6fe5ed0ab...
# 3   https://dl.airtable.com/.attachments/ca10936f8...
# 4   https://dl.airtable.com/.attachments/b9af8452c...
# 5   https://dl.airtable.com/.attachments/053f189b4...
# 6   https://dl.airtable.com/.attachments/af76d5166...
# 7   https://dl.airtable.com/.attachments/9f2346d1d...
# 8   https://dl.airtable.com/.attachments/158404769...
# 9   https://dl.airtable.com/.attachments/9fdb700e8...
# 10  https://dl.airtable.com/.attachments/198f07e19...
# 11  https://dl.airtable.com/.attachments/db3690fc2...
# 12  https://dl.airtable.com/.attachments/b8b94f63d...
# 13  https://dl.airtable.com/.attachments/d97f77aa3...
# 14  https://dl.airtable.com/.attachments/60652ecfe...
# 15  https://dl.airtable.com/.attachments/2bba5361c...
# 16  https://dl.airtable.com/.attachments/4009867b0...
# 17  https://dl.airtable.com/.attachments/c76c125ed...
# 18  https://dl.airtable.com/.attachments/63879fb92...
# 19  https://dl.airtable.com/.attachments/48d091036...
# 20  https://dl.airtable.com/.attachments/35b876752...
